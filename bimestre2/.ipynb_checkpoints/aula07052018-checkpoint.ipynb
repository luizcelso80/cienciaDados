# %% [markdown]
# O teorema de Bayes
#
# O teorema de Bayes é um relacionamento
# entre as probabilidades condicional de
# dois eeventos.
# Uma probabilidade condicional comumente escrita
# por P(A|B) é a probabilidade do evento A
# ocorrer dado que sabemos que o evento B já
# aconteceu.
#
# O teorema de Bayes determina que:
#
#     P(A|B) = P(B|A) * P(A) / P(B)
#
#     É valido dizermos que trata-se da probabilidade
#     de A e B acontecerem, assim podemos escrever:
#
#         P(A and B) = P(A) P(B|A)
#
#     Também é verdade dizer que:
#
#         P(B and A) = P(B) P(A|B)
#
#
#         ======================================
#         =                                    =
#         =                                    =
#         =                                    =
#         =                                    =
#         =                                    =
#         =                                    =
#         =                                    =
#         ======================================
#
#
#
#
#         P(A) =  #
#                # #
#                # #
#                # #
#                 #

# %% [markdown]
# Exemplo:
#     Em uma sacola há 2 moedas.Uma honesta e outra desonesta formada por duas faces caras.
#     Alguem tira da sacola uma moeda ao acaso e nota que saiu a face cara.Quais são as chances
#     de ter saído a moeda honesta.

# %% [markdown]
# Variaveis Aleatorias
# São variaveis cujos possiveis valores possuem uma
# distribuição de probabilidade associada uma variavel
# aleatoria bem simples é igual a 1 se sair cara e 0 se sair coroa.
# Uma variavel mais complicada é aquela cujo valor se refere a soma
# de vezes que saiu cara em 10 lancamentos de uma moeda honesta.
#
# A distribuicao associada define as probabilidades que a variavel possui
# ded assumir cada um de seus possiveis valores.
#
# No exemplo da moeda, a distribuicao de probabilidade associa a probabilidade de 50%
# da variavel assumir o valor 1(cara) e 50% de assumir o valor 0(coroa).
#
# As variaveis aleatorias podem ser condicionadas a eventos.No exemplo dos dois filhos serem meninas ou moleques, se X for a variavel que representa o numero de meninas, X = 0 com probabilidade de 1/4, 1 com probabilidade de 1/2 e 2 com probabilidade de 1/4.

# %%
"""funcao de densidade para a distribuicao uniforme (Pdf)"""
import math
import matplotlib.pyplot as plt
from __future__ import division

def uniform_pdf(x):
    return 1 if x >= 0 and x < 1 else 0


"""Funcao de distribuicao cumulativa (Cdf)"""

def uniform_cdf(x):
    if x < 0: return 0
    elif x < 1: return x
    else: return 1
    
"""Funcao da distribuicao normal"""

def normal_pdf(x, mu = 0, sigma = 1):
    sqrt_two_pi = math.sqrt(2 * math.pi)
    return (math.exp(-(x - mu) ** 2 / 2 / sigma ** 2) / (sqrt_two_pi * sigma))

xs = [x / 10.0 for x in range(-50, 50)]
plt.plot(xs,[normal_pdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_pdf(x,sigma=2) for x in xs],'--',label='mu=0,sigma=2')
plt.plot(xs,[normal_pdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
plt.plot(xs,[normal_pdf(x,mu=-1) for x in xs],'-.',label='mu=-1,sigma=1')
plt.legend()
plt.title("Various Normal pdfs")
plt.show()
